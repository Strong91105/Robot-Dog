# %% [markdown]
# # Retrain YOLO model
#
# In this notebook, we will use a simple way to retrain a yolo model on our custom dataset. More information can be found here https://docs.ultralytics.com/tasks/detect/#how-do-i-train-a-yolo11-model-on-my-custom-dataset
#
# Before starting the training, don't forget to create a yaml file  as well as arrange your dataset as instructed here https://docs.ultralytics.com/datasets/detect/#ultralytics-yolo-format

# %%
# import packages
from ultralytics import YOLO

# load a base pretrained model
model = YOLO("yolo11n.pt")

# %%
# Run this line to train your model. There are several arguments you can add or edit
# You can read the documents to understand more
model.train(data="ImgDet.yaml", epochs=100, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.3.234 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.221 🚀 Python-3.10.12 torch-2.9.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 9853MiB)
# ...

# %%
# Then try your model 
model = YOLO("best.pt")
model.train(data="ImgDet.yaml", epochs=100, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.3.234 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.221 🚀 Python-3.10.12 torch-2.9.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 9853MiB)
# ...
